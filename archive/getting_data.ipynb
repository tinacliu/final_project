# %% [markdown]
# <h2>Getting the data</h2>

# %% [markdown]
# <h4>Zoopla API</h4>

# %%
# %load_ext autoreload
# %autoreload 2

import lib
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# note API call is limited to 100 calls per hour
# all_results = []
call = lib.DataGetter()

# %%
result = call.getAllListings('London',99,100, False)
all_results += result
# Out:
# running API page 99 to 100
# Error
# http://api.zoopla.co.uk/api/v1/property_listings.json?area=London&radius=0&category=residential&listing_status=rent&include_rented=1&page_size=100&page_number=100&api_key=pn3zu33e9ympx94s485pfved

# %%
postcodes[52:]
# Out:
# ['E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14']

# %%
for postcode in postcodes[52:]:
    result = call.getAllListings(postcode)
    all_results += result
    print(postcode)
# Out:
# Success
# E4
# Success
# E5
# Success
# E6
# Success
# E7
# Success
# Success
# Success
# E8
# Success
# E9
# Success
# Success
# E10
# Success
# Success
# E11
# Success
# E12
# Success
# E13
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# Success
# E14

# %%
len(postcodes)
# Out:
# 63

# %%
len(all_results)
# Out:
# 50974

# %%
df = json_normalize(all_results)

# %%
df.listing_id.value_counts().head(20)
# Out:
# 52821783    5
# 49312737    5
# 53740188    5
# 51221646    5
# 52727577    5
# 50145166    5
# 53190942    5
# 53420608    5
# 53848002    5
# 53269560    5
# 53343007    5
# 52059262    4
# 49358511    4
# 46477187    4
# 53703919    4
# 45995871    4
# 53812590    4
# 39589237    4
# 48514510    4
# 45181458    4
# Name: listing_id, dtype: int64

# %%
print(df.shape)
# Out:
# (50974, 56)

# %%
df[df['listing_id']=='52624096']
# Out:
#                                agent_address  \
# 688  Bow Bridge Wharf, 1 High Street, London
# 700  Bow Bridge Wharf, 1 High Street, London
#
#                                             agent_logo agent_name  \
# 688  https://st.zoocdn.com/zoopla_static_agent_logo...  Dockley's
# 700  https://st.zoocdn.com/zoopla_static_agent_logo...  Dockley's
#
#        agent_phone available_from_display  bills_included     category  \
# 688  020 8115 8380                    NaN             NaN  Residential
# 700  020 8115 8380                    NaN             NaN  Residential
#
#      country country_code  county  ... price_modifier   property_type  \
# 688  England           gb  London  ...            NaN  Terraced house
# 700  England           gb  London  ...            NaN  Terraced house
#
#     rental_prices.accurate rental_prices.per_month rental_prices.per_week  \
# 688               per_week                   22750                   5250
# ...

# %%
df.to_csv('./data/london_rental_full.csv', index=False)

# %%
df.head().T
# Out:
#                                                                                         0  \
# agent_address                                         43 Berkeley Square, Mayfair, London
# agent_logo                              https://st.zoocdn.com/zoopla_static_agent_logo...
# agent_name                                                                   Oliver James
# agent_phone                                                                 020 8033 8929
# available_from_display                                              Available immediately
# bills_included                                                                        NaN
# category                                                                      Residential
# country                                                                              None
# country_code                                                                           gb
# ...
